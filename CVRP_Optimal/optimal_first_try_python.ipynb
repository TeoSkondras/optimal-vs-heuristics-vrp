# %%
from cvrp_parser import parse_cvrplib_uchoa_2014

# %%
import os
os.getcwd()
# Out:
# '/Users/constantinosbarmpouris/Documents/MIT/15.C57 Optimization Methods/Project/optimal-vs-heuristics-vrp/CVRP_Heuristic'

# %%
# read the file Uchoa_et_al_2014/X-n101-k25.vrp
# NOTE: the VRP files live in the nested 'X/' directory under the dataset folder
file_path = 'Uchoa et al - Vrp-Set-X/X/X-n101-k25.vrp'
#load the text into a string
with open(file_path, 'r') as file:
    vrp_text = file.read()
# parse the CVRP data
inst  = parse_cvrplib_uchoa_2014(vrp_text)

# %%
print(inst.name, inst.n_customers, inst.capacity, inst.edge_weight_type)
print("Depot coords:", inst.coords[0])
print("First customer coords:", inst.coords[1])
print("Distance(0,1):", inst.dist(0,1))
# Out:
# X-n101-k25 100 206 EUC_2D
# Depot coords: [365. 689.]
# First customer coords: [146. 180.]
# Distance(0,1): 554.1137067425782

# %%
# print the first 5 customers' demands
print("First 5 customers' demands:", inst.demand[1:6])
# Out:
# First 5 customers' demands: [38 51 73 70 58]

# %%
#

# %%
# --- Optimal CVRP (MIP) using Gurobi: single-commodity flow (SCF) formulation
# Requires Gurobi (gurobipy). Set a short TimeLimit for interactive runs.

try:
    import gurobipy as gp
    from gurobipy import GRB
except Exception as e:
    raise ImportError("gurobipy is required to run the MIP. Install/configure Gurobi and its Python API. Original error: {}".format(e))

# Build model from `inst` (parsed above). `inst.coords` has shape (n+1,2); `inst.demand` length n+1; depot is index 0.
n_customers = inst.n_customers
N = list(range(n_customers + 1))  # 0..n where 0 is depot
demand = list(map(int, inst.demand))
capacity = int(inst.capacity)

# Precompute distances (use inst.dist to remain consistent)
dist = [[inst.dist(i, j) for j in N] for i in N]

m = gp.Model("CVRP_SCF")
# Binary arc variables x[i,j] (i->j). We do not allow i==j.
x = m.addVars(N, N, vtype=GRB.BINARY, name='x')
# Continuous flow variables f[i,j] representing load sent on arc i->j (0..capacity).
f = m.addVars(N, N, lb=0.0, ub=capacity, name='f')

# Disable self arcs (force zero)
for i in N:
    m.addConstr(x[i,i] == 0)
    m.addConstr(f[i,i] == 0)

# Each customer must have exactly one incoming and one outgoing arc
for k in range(1, n_customers+1):
    m.addConstr(gp.quicksum(x[k, j] for j in N if j != k) == 1, name=f"out_{k}")
    m.addConstr(gp.quicksum(x[i, k] for i in N if i != k) == 1, name=f"in_{k}")

# Flow conservation: for each customer k, flow in - flow out = demand[k]
for k in range(1, n_customers+1):
    m.addConstr(gp.quicksum(f[i, k] for i in N if i != k) - gp.quicksum(f[k, j] for j in N if j != k) == demand[k], name=f"flow_cons_{k}")

# Link flow and x: f[i,j] <= capacity * x[i,j]
for i in N:
    for j in N:
        if i != j:
            m.addConstr(f[i, j] <= capacity * x[i, j], name=f"cap_link_{i}_{j}")

# Total flow out of depot equals total demand (sum of customer demands)
total_demand = sum(demand[1:])
m.addConstr(gp.quicksum(f[0, j] for j in range(1, n_customers+1)) == total_demand, name='depot_outflow')

# Objective: minimize total distance traveled
m.setObjective(gp.quicksum(dist[i][j] * x[i, j] for i in N for j in N if i != j), GRB.MINIMIZE)

# Tuning: interactive-friendly limits (adjust as needed)
m.Params.TimeLimit = 60  # seconds (set to None or larger for higher-quality solutions)
m.Params.OutputFlag = 1

print('Model: vars=', m.NumVars, 'constrs=', m.NumConstrs)
m.optimize()

if m.Status == GRB.OPTIMAL or m.Status == GRB.TIME_LIMIT or m.Status == GRB.SUBOPTIMAL:
    # Extract chosen arcs
    arcs = [(i, j) for i in N for j in N if i != j and x[i, j].X > 0.5]
    print(f"Solver status: {m.Status}, objective: {m.ObjVal if m.SolCount>0 else None}, arcs: {len(arcs)}")
    # Reconstruct routes from arcs (walk from depot until return)
    succ = {i: j for i, j in arcs}
    routes = []
    used = set()
    for j in range(1, n_customers+1):
        if j in used:
            continue
        # find route start: follow back from j until predecessor is depot or non-existent
        # Build route by starting at depot and following succ links
        route = [0]
        cur = 0
        while True:
            if cur not in succ:
                break
            nxt = succ[cur]
            route.append(nxt)
            used.add(nxt)
            cur = nxt
            if cur == 0:
                break
        routes.append(route)
    # Print routes in readable form (ignore trivial empty ones)
    for r_idx, r in enumerate(routes, start=1):
        # compute route demand and length
        if len(r) <= 1:
            continue
        route_demand = sum(demand[i] for i in r if i != 0)
        route_length = sum(inst.dist(r[i], r[i+1]) for i in range(len(r)-1))
        print(f"Route {r_idx}: {r}  demand={route_demand}  length={route_length:.2f}")
else:
    print('Optimization did not return a solution. Status code:', m.Status)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 5
#       4 try:
# ----> 5     import gurobipy as gp
#       6     from gurobipy import GRB
#
# ModuleNotFoundError: No module named 'gurobipy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 8
#       6     from gurobipy import GRB
#       7 except Exception as e:
# ----> 8     raise ImportError("gurobipy is required to run the MIP. Install/configure Gurobi and its Python API. Original error: {}".format(e))
#      10 # Build model from `inst` (parsed above). `inst.coords` has shape (n+1,2); `inst.demand` length n+1; depot is index 0.
#      11 n_customers = inst.n_customers
#
# ImportError: gurobipy is required to run the MIP. Install/configure Gurobi and its Python API. Original error: No module named 'gurobipy'

# %%
# Fallback: try Gurobi, otherwise solve the SCF MIP with PuLP (CBC)
# This cell attempts to import gurobipy first. If not available, it will try to use PuLP + CBC.
# If PuLP is not installed, it will attempt to install it via pip (may require internet and permissions).

import sys

try:
    import gurobipy as gp
    from gurobipy import GRB
    print("gurobipy is available — prefer running the earlier Gurobi cell instead of this fallback.")
    # Optionally you could call the Gurobi model-building code here.
except Exception:
    print("gurobipy not available; falling back to PuLP + CBC (open-source)")
    try:
        import pulp
    except Exception:
        print("PuLP not installed — attempting to install via pip. This requires internet access.")
        try:
            import subprocess
            subprocess.check_call([sys.executable, "-m", "pip", "install", "pulp>=2.6.0"])
            import pulp
        except Exception as e:
            raise ImportError("PuLP is required for the fallback and could not be installed automatically. Please run: pip install pulp") from e

    # Build the SCF MIP using PuLP
    # Prepare data from `inst` which should already be defined above
    n_customers = inst.n_customers
    N = list(range(n_customers + 1))
    demand = list(map(int, inst.demand))
    capacity = int(inst.capacity)
    dist = [[inst.dist(i, j) for j in N] for i in N]

    model = pulp.LpProblem('CVRP_SCF_PuLP', pulp.LpMinimize)

    # Variables
    x = pulp.LpVariable.dicts('x', (N, N), lowBound=0, upBound=1, cat=pulp.LpBinary)
    f = pulp.LpVariable.dicts('f', (N, N), lowBound=0, upBound=capacity, cat=pulp.LpContinuous)

    # Objective
    model += pulp.lpSum(dist[i][j] * x[i][j] for i in N for j in N if i != j)

    # Constraints
    # No self arcs
    for i in N:
        model += x[i][i] == 0
        model += f[i][i] == 0

    # Each customer has exactly one incoming and one outgoing arc
    for k in range(1, n_customers + 1):
        model += pulp.lpSum(x[k][j] for j in N if j != k) == 1
        model += pulp.lpSum(x[i][k] for i in N if i != k) == 1

    # Flow conservation: for customers, inflow - outflow = demand[k]
    for k in range(1, n_customers + 1):
        model += pulp.lpSum(f[i][k] for i in N if i != k) - pulp.lpSum(f[k][j] for j in N if j != k) == demand[k]

    # Link flow and x: f[i,j] <= capacity * x[i,j]
    for i in N:
        for j in N:
            if i != j:
                model += f[i][j] <= capacity * x[i][j]

    # Total flow out of depot equals total demand
    total_demand = sum(demand[1:])
    model += pulp.lpSum(f[0][j] for j in range(1, n_customers + 1)) == total_demand

    # Solve with CBC, set time limit (in seconds) for interactive runs
    solver = pulp.PULP_CBC_CMD(timeLimit=60, msg=True)
    print('Model built. Solving with CBC...')
    result = model.solve(solver)

    status = pulp.LpStatus.get(result, None)
    print('Solver status:', status)

    if pulp.LpStatus[result] in ('Optimal', 'Not Solved', 'Integer Feasible') or pulp.LpStatus[result] == 'Optimal':
        arcs = [(i, j) for i in N for j in N if i != j and pulp.value(x[i][j]) is not None and pulp.value(x[i][j]) > 0.5]
        print(f"Arcs selected: {len(arcs)}")
        succ = {i: j for i, j in arcs}
        routes = []
        used = set()
        for j in range(1, n_customers + 1):
            if j in used:
                continue
            route = [0]
            cur = 0
            while True:
                if cur not in succ:
                    break
                nxt = succ[cur]
                route.append(nxt)
                used.add(nxt)
                cur = nxt
                if cur == 0:
                    break
            routes.append(route)
        for r_idx, r in enumerate(routes, start=1):
            if len(r) <= 1:
                continue
            route_demand = sum(demand[i] for i in r if i != 0)
            route_length = sum(inst.dist(r[i], r[i+1]) for i in range(len(r)-1))
            print(f"Route {r_idx}: {r}  demand={route_demand}  length={route_length:.2f}")
    else:
        print('No feasible solution found. Status:', pulp.LpStatus[result])
# Out:
# gurobipy not available; falling back to PuLP + CBC (open-source)
# Model built. Solving with CBC...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/s7/fy136dw90dsb64z_hj492ptm0000gn/T/3d4a571ace7041959f65fd7bb8886497-pulp.mps -sec 60 -timeMode elapsed -branch -printingOptions all -solution /var/folders/s7/fy136dw90dsb64z_hj492ptm0000gn/T/3d4a571ace7041959f65fd7bb8886497-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10608 COLUMNS
# At line 101613 RHS
# At line 112217 BOUNDS
# At line 132620 ENDATA
# Problem MODEL has 10603 rows, 20402 columns and 60502 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 24041.9 - 1.53 seconds
# Cgl0002I 101 variables fixed
# Cgl0004I processed model has 10401 rows, 20200 columns (10100 integer (10100 of which binary)) and 60300 elements
# Cbc0038I Initial state - 278 integers unsatisfied sum - 77.3641
# Cbc0038I Pass   1: (2.11 seconds) suminf.   23.52913 (95) obj. 32856.7 iterations 6849
# Cbc0038I Pass   2: (2.16 seconds) suminf.   17.13107 (76) obj. 34312.3 iterations 946
# Cbc0038I Pass   3: (2.19 seconds) suminf.   15.21845 (71) obj. 34297.5 iterations 701
# Cbc0038I Pass   4: (2.26 seconds) suminf.    9.93204 (57) obj. 37302.7 iterations 1394
# Cbc0038I Pass   5: (2.29 seconds) suminf.    9.07767 (56) obj. 37873 iterations 360
# Cbc0038I Pass   6: (2.33 seconds) suminf.    6.36893 (46) obj. 39207.2 iterations 798
# Cbc0038I Pass   7: (2.35 seconds) suminf.    5.57767 (47) obj. 39347.3 iterations 374
# Cbc0038I Pass   8: (2.41 seconds) suminf.    4.81068 (34) obj. 41456.9 iterations 1461
# Cbc0038I Pass   9: (2.43 seconds) suminf.    4.01942 (35) obj. 41371.9 iterations 535
# Cbc0038I Pass  10: (2.48 seconds) suminf.    1.50971 (21) obj. 44737.8 iterations 845
# Cbc0038I Pass  11: (2.50 seconds) suminf.    0.85922 (18) obj. 44784.1 iterations 275
# Cbc0038I Pass  12: (2.54 seconds) suminf.    0.02913 (3) obj. 47913.5 iterations 764
# Cbc0038I Pass  13: (2.58 seconds) suminf.    0.00000 (0) obj. 49051.1 iterations 315
# Cbc0038I Solution found of 49051.1
# Cbc0038I Relaxing continuous gives 49051.1
# Cbc0038I Before mini branch and bound, 9712 integers at bound fixed and 9859 continuous
# Cbc0038I Full problem 10401 rows 20200 columns, reduced to 360 rows 443 columns
# Cbc0038I Mini branch and bound improved solution from 49051.1 to 36193 (2.87 seconds)
# Cbc0038I Round again with cutoff of 34977.9
# Cbc0038I Pass  14: (2.90 seconds) suminf.   23.52913 (95) obj. 32856.7 iterations 0
# Cbc0038I Pass  15: (3.01 seconds) suminf.   17.73735 (70) obj. 34977.9 iterations 1995
# Cbc0038I Pass  16: (3.04 seconds) suminf.   15.53398 (70) obj. 34977.9 iterations 355
# Cbc0038I Pass  17: (3.21 seconds) suminf.   11.78923 (66) obj. 34977.9 iterations 3314
# Cbc0038I Pass  18: (3.27 seconds) suminf.   10.67606 (65) obj. 34977.9 iterations 858
# Cbc0038I Pass  19: (3.32 seconds) suminf.   10.10294 (63) obj. 34977.9 iterations 485
# Cbc0038I Pass  20: (3.42 seconds) suminf.    6.06544 (51) obj. 34977.9 iterations 1631
# Cbc0038I Pass  21: (3.50 seconds) suminf.    4.52372 (46) obj. 34977.9 iterations 1135
# Cbc0038I Pass  22: (3.62 seconds) suminf.    5.12912 (50) obj. 34977.9 iterations 1832
# Cbc0038I Pass  23: (3.65 seconds) suminf.    4.51754 (44) obj. 34977.9 iterations 125
# Cbc0038I Pass  24: (3.67 seconds) suminf.    4.12936 (46) obj. 34977.9 iterations 207
# Cbc0038I Pass  25: (3.77 seconds) suminf.    8.55825 (43) obj. 34782.4 iterations 1515
# Cbc0038I Pass  26: (3.81 seconds) suminf.    6.03398 (36) obj. 34895.8 iterations 401
# Cbc0038I Pass  27: (3.87 seconds) suminf.    4.48503 (35) obj. 34977.9 iterations 782
# Cbc0038I Pass  28: (3.92 seconds) suminf.    3.93112 (28) obj. 34977.9 iterations 592
# Cbc0038I Pass  29: (3.98 seconds) suminf.    2.71658 (25) obj. 34977.9 iterations 817
# Cbc0038I Pass  30: (4.01 seconds) suminf.    1.90777 (27) obj. 34865 iterations 460
# Cbc0038I Pass  31: (4.09 seconds) suminf.    5.16390 (39) obj. 34977.9 iterations 1023
# Cbc0038I Pass  32: (4.16 seconds) suminf.    3.54318 (33) obj. 34977.9 iterations 1043
# Cbc0038I Pass  33: (4.19 seconds) suminf.    3.54111 (36) obj. 34977.9 iterations 127
# Cbc0038I Pass  34: (4.26 seconds) suminf.    3.86154 (36) obj. 34977.9 iterations 975
# Cbc0038I Pass  35: (4.32 seconds) suminf.    2.63740 (43) obj. 34977.9 iterations 836
# Cbc0038I Pass  36: (4.46 seconds) suminf.    9.12614 (44) obj. 34977.9 iterations 1909
# Cbc0038I Pass  37: (4.54 seconds) suminf.    5.99336 (38) obj. 34977.9 iterations 1190
# Cbc0038I Pass  38: (4.66 seconds) suminf.    4.10570 (27) obj. 34977.9 iterations 2076
# Cbc0038I Pass  39: (4.70 seconds) suminf.    3.49720 (28) obj. 34977.9 iterations 386
# Cbc0038I Pass  40: (4.71 seconds) suminf.    3.49720 (28) obj. 34977.9 iterations 16
# Cbc0038I Pass  41: (4.79 seconds) suminf.    4.37462 (28) obj. 34977.9 iterations 1101
# Cbc0038I Pass  42: (4.82 seconds) suminf.    3.73489 (30) obj. 34977.9 iterations 415
# Cbc0038I Pass  43: (4.89 seconds) suminf.    6.04028 (34) obj. 34977.9 iterations 840
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9597 integers at bound fixed and 9785 continuous
# Cbc0038I Full problem 10401 rows 20200 columns, reduced to 492 rows 698 columns
# Cbc0038I Mini branch and bound improved solution from 36193 to 33692.7 (5.33 seconds)
# Cbc0038I Round again with cutoff of 31762.6
# Cbc0038I Pass  43: (5.63 seconds) suminf.   23.12741 (98) obj. 31762.6 iterations 994
# Cbc0038I Pass  44: (5.79 seconds) suminf.   17.14492 (83) obj. 31762.6 iterations 2968
# Cbc0038I Pass  45: (5.81 seconds) suminf.   17.13887 (86) obj. 31762.6 iterations 38
# Cbc0038I Pass  46: (5.98 seconds) suminf.   11.33351 (76) obj. 31762.6 iterations 2895
# Cbc0038I Pass  47: (6.04 seconds) suminf.   11.27368 (82) obj. 31762.6 iterations 574
# Cbc0038I Pass  48: (6.18 seconds) suminf.    9.28747 (59) obj. 31762.6 iterations 2238
# Cbc0038I Pass  49: (6.28 seconds) suminf.    6.76860 (57) obj. 31762.6 iterations 1365
# Cbc0038I Pass  50: (6.31 seconds) suminf.    6.58287 (61) obj. 31762.6 iterations 281
# Cbc0038I Pass  51: (6.43 seconds) suminf.    7.23252 (46) obj. 31762.6 iterations 1869
# Cbc0038I Pass  52: (6.49 seconds) suminf.    4.03536 (53) obj. 31762.6 iterations 736
# Cbc0038I Pass  53: (6.56 seconds) suminf.    3.84966 (52) obj. 31762.6 iterations 956
# Cbc0038I Pass  54: (6.60 seconds) suminf.    3.71907 (48) obj. 31762.6 iterations 487
# Cbc0038I Pass  55: (6.78 seconds) suminf.    7.56311 (47) obj. 31762.6 iterations 2746
# Cbc0038I Pass  56: (6.85 seconds) suminf.    5.54009 (50) obj. 31762.6 iterations 1240
# Cbc0038I Pass  57: (6.88 seconds) suminf.    3.20685 (44) obj. 31762.6 iterations 146
# Cbc0038I Pass  58: (7.00 seconds) suminf.    7.35762 (48) obj. 31762.6 iterations 2172
# Cbc0038I Pass  59: (7.03 seconds) suminf.    6.96551 (48) obj. 31762.6 iterations 204
# Cbc0038I Pass  60: (7.10 seconds) suminf.    6.37629 (47) obj. 31762.6 iterations 1058
# Cbc0038I Pass  61: (7.16 seconds) suminf.    5.21052 (53) obj. 31762.6 iterations 560
# Cbc0038I Pass  62: (7.19 seconds) suminf.    4.16750 (51) obj. 31762.6 iterations 263
# Cbc0038I Pass  63: (7.29 seconds) suminf.    5.60767 (49) obj. 31762.6 iterations 1383
# Cbc0038I Pass  64: (7.33 seconds) suminf.    4.72449 (53) obj. 31762.6 iterations 339
# Cbc0038I Pass  65: (7.42 seconds) suminf.    5.75969 (49) obj. 31762.6 iterations 1317
# Cbc0038I Pass  66: (7.48 seconds) suminf.    4.42142 (54) obj. 31762.6 iterations 688
# Cbc0038I Pass  67: (7.53 seconds) suminf.    4.04462 (51) obj. 31762.6 iterations 490
# Cbc0038I Pass  68: (7.64 seconds) suminf.    5.49638 (36) obj. 31762.6 iterations 1793
# Cbc0038I Pass  69: (7.72 seconds) suminf.    3.50163 (53) obj. 31762.6 iterations 1210
# Cbc0038I Pass  70: (7.76 seconds) suminf.    3.23629 (51) obj. 31762.6 iterations 271
# Cbc0038I Pass  71: (7.86 seconds) suminf.    5.13115 (33) obj. 31762.6 iterations 1465
# Cbc0038I Pass  72: (7.93 seconds) suminf.    4.74659 (39) obj. 31762.6 iterations 1195
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9566 integers at bound fixed and 9761 continuous
# Cbc0038I Full problem 10401 rows 20200 columns, reduced to 519 rows 753 columns
# Cbc0038I Mini branch and bound did not improve solution (8.31 seconds)
# Cbc0038I After 8.31 seconds - Feasibility pump exiting with objective of 33692.7 - took 6.32 seconds
# Cbc0012I Integer solution of 33692.719 found by feasibility pump after 0 iterations and 0 nodes (8.77 seconds)
# Cbc0038I Full problem 10401 rows 20200 columns, reduced to 501 rows 517 columns
# Cbc0031I 597 added rows had average density of 354.96315
# Cbc0013I At root node, 597 cuts changed objective from 24041.898 to 25443.216 in 50 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (380 active)  in 2.750 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 374 row cuts average 738.0 elements, 0 column cuts (0 active)  in 2.551 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.465 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.071 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 8975 row cuts average 364.4 elements, 0 column cuts (0 active)  in 1.913 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 191 row cuts average 109.6 elements, 0 column cuts (0 active)  in 0.601 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 163 row cuts average 278.1 elements, 0 column cuts (0 active)  in 0.814 seconds - new frequency is -100
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 33692.719 (best possible 25443.216), took 52450 iterations and 0 nodes (61.28 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 24041.9 to 25443.2
# Probing was tried 50 times and created 0 cuts of which 380 were active after adding rounds of cuts (2.750 seconds)
# Gomory was tried 50 times and created 374 cuts of which 0 were active after adding rounds of cuts (2.551 seconds)
# Knapsack was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.465 seconds)
# Clique was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.071 seconds)
# MixedIntegerRounding2 was tried 50 times and created 8975 cuts of which 0 were active after adding rounds of cuts (1.913 seconds)
# FlowCover was tried 50 times and created 191 cuts of which 0 were active after adding rounds of cuts (0.601 seconds)
# TwoMirCuts was tried 50 times and created 163 cuts of which 0 were active after adding rounds of cuts (0.814 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                33692.71919518
# Lower bound:                    25443.216
# Gap:                            0.32
# Enumerated nodes:               0
# Total iterations:               52450
# Time (CPU seconds):             60.83
# Time (Wallclock seconds):       62.25
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       60.90   (Wallclock seconds):       62.33
#
# Solver status: Optimal
# Arcs selected: 133
# Route 1: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 2: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 3: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 4: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 5: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 6: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 7: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 8: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 9: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 10: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 11: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 12: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 13: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 14: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 15: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 16: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 17: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 18: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 19: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 20: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 21: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 22: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 23: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 24: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 25: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 26: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 27: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 28: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 29: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 30: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 31: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 32: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 33: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 34: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 35: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 36: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 37: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 38: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 39: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 40: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 41: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 42: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 43: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 44: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 45: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 46: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 47: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 48: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 49: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 50: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 51: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 52: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 53: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 54: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 55: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 56: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 57: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 58: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 59: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 60: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 61: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 62: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 63: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 64: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 65: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 66: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 67: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 68: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 69: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 70: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 71: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 72: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 73: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 74: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 75: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 76: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 77: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 78: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 79: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 80: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 81: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 82: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 83: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 84: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 85: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 86: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 87: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 88: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 89: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 90: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 91: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 92: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 93: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 94: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 95: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 96: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 97: [0, 97, 91, 51, 0]  demand=203  length=1148.85

# %%
# output the optimal routes and their total length and demand, if a solution was found
def print_routes(routes, demand, inst):
    for r_idx, r in enumerate(routes, start=1):
        if len(r) <= 1:
            continue
        route_demand = sum(demand[i] for i in r if i != 0)
        route_length = sum(inst.dist(r[i], r[i+1]) for i in range(len(r)-1))
        print(f"Route {r_idx}: {r}  demand={route_demand}  length={route_length:.2f}")

print_routes(routes, demand, inst)
# Out:
# Route 1: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 2: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 3: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 4: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 5: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 6: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 7: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 8: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 9: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 10: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 11: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 12: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 13: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 14: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 15: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 16: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 17: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 18: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 19: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 20: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 21: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 22: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 23: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 24: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 25: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 26: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 27: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 28: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 29: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 30: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 31: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 32: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 33: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 34: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 35: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 36: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 37: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 38: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 39: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 40: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 41: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 42: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 43: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 44: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 45: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 46: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 47: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 48: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 49: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 50: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 51: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 52: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 53: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 54: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 55: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 56: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 57: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 58: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 59: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 60: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 61: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 62: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 63: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 64: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 65: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 66: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 67: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 68: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 69: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 70: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 71: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 72: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 73: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 74: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 75: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 76: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 77: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 78: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 79: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 80: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 81: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 82: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 83: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 84: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 85: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 86: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 87: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 88: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 89: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 90: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 91: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 92: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 93: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 94: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 95: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 96: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 97: [0, 97, 91, 51, 0]  demand=203  length=1148.85

# %%
# Compare the optimal solution to the given solution in the file "/Users/constantinosbarmpouris/Documents/MIT/15.C57 Optimization Methods/Project/optimal-vs-heuristics-vrp/CVRP_Heuristic/Uchoa et al - Vrp-Set-X/X/X-n101-k25.sol"
def parse_solution_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    routes = []
    for line in lines:  
        line = line.strip()
        if line.startswith("Route"):
            parts = line.split(":")
            if len(parts) > 1:
                route_str = parts[1].strip()
                route = list(map(int, route_str.split()))
                routes.append(route)
    return routes
solution_file_path = 'Uchoa et al - Vrp-Set-X/X/X-n101-k25.sol'
solution_routes = parse_solution_file(solution_file_path)
print("Solution routes from file:")
print_routes(solution_routes, demand, inst)
# Out:
# Solution routes from file:
# Route 1: [31, 46, 35]  demand=191  length=246.24
# Route 2: [15, 22, 41, 20]  demand=205  length=199.07
# Route 3: [1, 70, 54]  demand=201  length=310.57
# Route 4: [92, 9, 86]  demand=203  length=166.04
# Route 5: [68, 90, 84, 66]  demand=196  length=114.91
# Route 6: [76, 55, 16, 69]  demand=203  length=108.88
# Route 7: [4, 13, 74]  demand=189  length=269.12
# Route 8: [58, 12, 5]  demand=202  length=205.19
# Route 9: [18, 10, 39]  demand=206  length=196.51
# Route 10: [25, 65, 78, 42, 28]  demand=205  length=220.37
# Route 11: [7, 2, 45, 43, 29, 36, 72, 57]  demand=206  length=808.82
# Route 12: [87, 37, 6, 49, 14]  demand=206  length=631.76
# Route 13: [3, 77, 63]  demand=202  length=163.56
# Route 14: [44, 67, 88, 40]  demand=202  length=222.92
# Route 15: [82, 60, 59]  demand=205  length=81.58
# Route 16: [8, 17]  demand=172  length=56.08
# Route 17: [34, 64, 96, 48, 26, 47, 38]  demand=202  length=597.61
# Route 18: [80, 94, 56, 21]  demand=204  length=311.34
# Route 19: [71, 62, 99, 98, 89]  demand=203  length=224.85
# Route 20: [100, 61, 23]  demand=190  length=138.14
# Route 21: [19, 97, 27]  demand=197  length=215.46
# Route 22: [81, 51, 83]  demand=190  length=138.77
# Route 23: [50, 91, 52]  demand=206  length=394.48
# Route 24: [30, 85, 11, 79]  demand=184  length=249.33
# Route 25: [75, 93]  demand=176  length=109.12
# Route 26: [24, 95, 73, 53, 33, 32]  demand=201  length=582.86

# %%
# Compare the 2 solutions by computing total length and demand for each route, and the overall total length and demand. Print the results in a readable format.
def compute_solution_stats(routes, demand, inst):
    total_length = 0.0
    total_demand = 0
    for r_idx, r in enumerate(routes, start=1):
        if len(r) <= 1:
            continue
        route_demand = sum(demand[i] for i in r if i != 0)
        route_length = sum(inst.dist(r[i], r[i+1]) for i in range(len(r)-1))
        print(f"Route {r_idx}: {r}  demand={route_demand}  length={route_length:.2f}")
        total_length += route_length
        total_demand += route_demand
    print(f"Total demand: {total_demand}, Total length: {total_length:.2f}")
print("Optimal solution stats:")
compute_solution_stats(routes, demand, inst)
print("Given solution stats:")
compute_solution_stats(solution_routes, demand, inst)
# Out:
# Optimal solution stats:
# Route 1: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 2: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 3: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 4: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 5: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 6: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 7: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 8: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 9: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 10: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 11: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 12: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 13: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 14: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 15: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 16: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 17: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 18: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 19: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 20: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 21: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 22: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 23: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 24: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 25: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 26: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 27: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 28: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 29: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 30: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 31: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 32: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 33: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 34: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 35: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 36: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 37: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 38: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 39: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 40: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 41: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 42: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 43: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 44: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 45: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 46: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 47: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 48: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 49: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 50: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 51: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 52: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 53: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 54: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 55: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 56: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 57: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 58: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 59: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 60: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 61: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 62: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 63: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 64: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 65: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 66: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 67: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 68: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 69: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 70: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 71: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 72: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 73: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 74: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 75: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 76: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 77: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 78: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 79: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 80: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 81: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 82: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 83: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 84: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 85: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 86: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 87: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 88: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 89: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 90: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 91: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 92: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 93: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 94: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 95: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 96: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Route 97: [0, 97, 91, 51, 0]  demand=203  length=1148.85
# Total demand: 19691, Total length: 111438.44
# Given solution stats:
# Route 1: [31, 46, 35]  demand=191  length=246.24
# Route 2: [15, 22, 41, 20]  demand=205  length=199.07
# Route 3: [1, 70, 54]  demand=201  length=310.57
# Route 4: [92, 9, 86]  demand=203  length=166.04
# Route 5: [68, 90, 84, 66]  demand=196  length=114.91
# Route 6: [76, 55, 16, 69]  demand=203  length=108.88
# Route 7: [4, 13, 74]  demand=189  length=269.12
# Route 8: [58, 12, 5]  demand=202  length=205.19
# Route 9: [18, 10, 39]  demand=206  length=196.51
# Route 10: [25, 65, 78, 42, 28]  demand=205  length=220.37
# Route 11: [7, 2, 45, 43, 29, 36, 72, 57]  demand=206  length=808.82
# Route 12: [87, 37, 6, 49, 14]  demand=206  length=631.76
# Route 13: [3, 77, 63]  demand=202  length=163.56
# Route 14: [44, 67, 88, 40]  demand=202  length=222.92
# Route 15: [82, 60, 59]  demand=205  length=81.58
# Route 16: [8, 17]  demand=172  length=56.08
# Route 17: [34, 64, 96, 48, 26, 47, 38]  demand=202  length=597.61
# Route 18: [80, 94, 56, 21]  demand=204  length=311.34
# Route 19: [71, 62, 99, 98, 89]  demand=203  length=224.85
# Route 20: [100, 61, 23]  demand=190  length=138.14
# Route 21: [19, 97, 27]  demand=197  length=215.46
# Route 22: [81, 51, 83]  demand=190  length=138.77
# Route 23: [50, 91, 52]  demand=206  length=394.48
# Route 24: [30, 85, 11, 79]  demand=184  length=249.33
# Route 25: [75, 93]  demand=176  length=109.12
# Route 26: [24, 95, 73, 53, 33, 32]  demand=201  length=582.86
# Total demand: 5147, Total length: 6963.58

# %%
def check_feasibility(routes, demand, capacity):
    n = len(demand)-1
    seen = []
    for r in routes:
        # Expect route either like [0, a, b, ..., 0] or [a,b,...] depending on format
        # Normalize: remove depot markers if present
        nodes = [v for v in r if v != 0]
        seen.extend(nodes)
        rd = sum(demand[v] for v in nodes)
        if rd > capacity:
            return False, f"Route {r} exceeds capacity ({rd} > {capacity})"
        for v in nodes:
            if v < 1 or v > n:
                return False, f"Invalid node index {v} in route {r}"
    # check coverage
    from collections import Counter
    cnt = Counter(seen)
    missing = [i for i in range(1, n+1) if cnt[i] == 0]
    dup = [i for i, c in cnt.items() if c > 1]
    if missing:
        return False, f"Missing customers: {missing[:10]}{'...' if len(missing)>10 else ''}"
    if dup:
        return False, f"Duplicate visits: {dup[:10]}{'...' if len(dup)>10 else ''}"
    return True, "Feasible (coverage and capacity OK)"

# Example usage:
ok, msg = check_feasibility(solution_routes, demand, capacity)
print(ok, msg)
# Out:
# True Feasible (coverage and capacity OK)
